# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from PIL import Image
from scipy import ndimage
from skimage import io

# %%
a = io.imread("predictions/prediction_1.png", flatten=True)
a = a[:, :]

# %%
np.shape(a)
# Out:
# (608, 608)

# %%
def ground_truth_processing(img, )
# Out:
#   File "<ipython-input-196-bf4d5dabd08a>", line 1
#     def ground_truth_processing(img, )
#                                       ^
# SyntaxError: invalid syntax

# %%
io.imshow(a)

# %%
b = ndimage.morphology.grey_opening(a, structure=np.zeros((4,4)))
c = b > 0.5
io.imshow(c)

# %%
c = 
c = ndimage.binary_erosion(c, structure=np.ones((4,4)))
c = ndimage.binary_propagation(c, mask=b)
io.imshow(c)

# %%
io.imshow(c)

# %%
img = mpimg.imread("training/images/satImage_001.png")

imgs = []
for i in range(5):
    imgs.append(img)

# %%
np.shape(imgs)
# Out:
# (5, 400, 400, 3)
